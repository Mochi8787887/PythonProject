# %% [markdown]
# # 註冊並登入 LINE Developer
#
# 前往 LINE Developers 網站，使用個人帳號登入。
# https://developers.line.biz/zh-hant/
#
# ![image.png](attachment:9793d8a7-1696-4a1a-9ff6-76adb423b71c.png)

# %% [markdown]
# # 建立 Provider
# ![image.png](attachment:71fefac6-6706-4992-a08e-214a07912dae.png)
